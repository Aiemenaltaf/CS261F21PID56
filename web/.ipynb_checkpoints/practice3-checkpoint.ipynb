# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
#install chrom webdriver
#webdriver can be downloaded from
#https://chromedriver.storage.googleapis.com/index.html?path=94.0.4606.41/
driver = webdriver.Chrome(executable_path=r'C:\Users\uswa nasir\Desktop\chromedriver_win32\chromedriver.exe')
products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings =[]
# discounts=[]
# ratings=[] #List to store rating of the product
for page in range(1,103):
    driver.get("https://www.daraz.pk/womens-dresses/?from=onesearch_category_1738&item_id=202832216&page="+str(page)+"&spm=a2a0e.searchlistcategory.card.1.5f8e27f3fkYocj")
    content = driver.page_source
    soup = BeautifulSoup(content)

# print(soup)
for a in soup.findAll('div',attrs={'class':'c3KeDq'}):
    name=a.find('div', attrs={'class':'c16H9d'})
    products.append(name.text)
    price=a.find('div', attrs={'class':'c3gUW0'})
    prices.append(price.text)
    if(a.find('div', attrs={'class':'c2JB4x c6Ntq9'})):
        rating=a.find('div', attrs={'class':'c2JB4x c6Ntq9'}).text
        ratings.append(rating)
    else:
        rating="No Ratingg Available"
        ratings.append(rating)
        
            
    
    
         
#     discount = a.find('span', attrs={'class':'c1hkC1'})
#     products.append(name.text)
#     prices.append(price.text)
#     ratings.append(rating.text)
#     discounts.append(discount.text)
print(len(products))
print(len(prices))
print(len(ratings))
# print(len(discounts))
df = pd.DataFrame({'Product Name':products,'Price':prices, 'Rating':ratings})
df.to_csv('ClothesInfo.csv', index=False, encoding='utf-8')
dataset = pd.DataFrame(data = df)
print(dataset)
# Out:
# 40
# 40
# 40
#                                          Product Name      Price  \
# 0      Blue and White Dress For Women - Winter Shirts    Rs. 254
# 1   KISHMISH Stitched Casual Chapter Two (2 Pcs) D...  Rs. 1,179
# 2   Lawn Printed Kurti with Printed Trouser For Girls    Rs. 500
# 3                      Skin and Black Frock For Women    Rs. 326
# 4           2 piece unstitched embrioded cotton dress  Rs. 2,649
# 5   Kishmish Summer Stiched Cultural Embroidered 2...  Rs. 1,199
# 6   Kishmish Elegant 2 Piece Bootcut Dress For Her...  Rs. 1,499
# 7           women fashion, girls accessories, dresses  Rs. 2,500
# 8   Women Two-piece Clothes Set, Solid Color Round...  Rs. 2,468
# 9   Women Sequin Mesh Long Sleeve Evening Party Co...  Rs. 1,070
# 10  Kishmish Elegant Embroidered Cape Kurti For He...  Rs. 1,099
# 11  Women Spaghetti Straps Mini Dress, Sling Sleev...  Rs. 1,368
# 12  Kishmish Pret Designer Net Sleeves Work Summer...    Rs. 899
# 13  KISHMISH Stitched Chapter Two Embroidered (2 P...  Rs. 1,333
# 14  Lollypop Pret Summer Stiched Tradtional Work a...  Rs. 1,199
# 15  Pack of red colour silk tassel for ladies dres...    Rs. 180
